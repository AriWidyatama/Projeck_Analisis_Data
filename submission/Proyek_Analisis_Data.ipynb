# %% [markdown]
# # Proyek Analisis Data: [Input Nama Dataset]
# - **Nama:** I Putu Suka Ari Widyatama
# - **Email:** widyatama04@gmail.com
# - **ID Dicoding:** oryshion

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Pertanyaan 1 : Bagaimana perbandingan penyewa casual dengan register pada setiap musim?
# - Pertanyaan 2 : Bagaimana statistik penyewaan sepeda dalam satu hati pada setiap musim?
# - Pertanyaan 3 : Bagaimana perkembangan pelanggan dalam setiap bulan?
# - Pertanyaan 4 : Pada jam berapa pelanggan paling sering menyewa sepeda?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
day_df = pd.read_csv("day.csv")
day_df.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-01       1   0     1        0        0           0
# 2        3  2011-01-01       1   0     1        0        1           1
# 3        4  2011-01-01       1   0     1        0        2           1
# 4        5  2011-01-01       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
hour_df = pd.read_csv("hour.csv")
hour_df.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %% [markdown]
# **Insight:**
# - Mengambil dan menampilkan Data Day
# - Mengambil dan menampilkan Data Hour

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# melihat missing value dan tipe data tidak cocok dari dataset day

# %%
day_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB

# %% [markdown]
# melihat duplikat data day

# %%
print("Jumlah duplikasi: ", day_df.duplicated().sum())
day_df.isna().sum()
# Out:
# Jumlah duplikasi:  0
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %% [markdown]
# melihat missing value dan tipe data tidak cocok dari dataset hour

# %%
hour_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      731 non-null    object
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB

# %% [markdown]
# melihat duplikat data hour

# %%
print("Jumlah duplikasi: ", hour_df.duplicated().sum())
hour_df.isna().sum()
# Out:
# Jumlah duplikasi:  0
# instant           0
# dteday        16648
# season            0
# yr                0
# mnth              0
# hr                0
# holiday           0
# weekday           0
# workingday        0
# weathersit        0
# temp              0
# atemp             0
# hum               0
# windspeed         0
# casual            0
# registered        0
# cnt               0
# dtype: int64

# %%
day_df.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean   366.000000    2.496580    0.500684    6.519836    0.028728    2.997264
# std    211.165812    1.110807    0.500342    3.451913    0.167155    2.004787
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.500000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    366.000000    3.000000    1.000000    7.000000    0.000000    3.000000
# 75%    548.500000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    731.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.683995    1.395349    0.495385    0.474354    0.627894    0.190486
# ...

# %%
hour_df.describe()
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# ...

# %% [markdown]
# **Insight:**
# - Dataset Day dan Hour sudah bersih tidak ada duplikat dan missing value
# - Terdapat Tipe Data yang tidak cocok untuk analisis pada bagian tanggal

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# memperbaiki tipe data dteday pada Dataset Day

# %%
day_df['dteday'] = pd.to_datetime(hour_df['dteday'])

# %% [markdown]
# memperbaiki tipe data dteday pada Dataset Hour

# %%
hour_df['dteday'] = pd.to_datetime(day_df['dteday'])

# %% [markdown]
# **Insight:**
# - Terdapat perbaikan tipe data pada kolom dteday menjadi datetime
# - xxx

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore ...

# %% [markdown]
# melihat sampel dari dataset day dan hour

# %%
day_df.sample(5)
# Out:
#      instant     dteday  season  yr  mnth  holiday  weekday  workingday  \
# 528      529 2011-01-24       2   1     6        0        2           1
# 722      723 2011-02-02       1   1    12        0        0           0
# 0          1 2011-01-01       1   0     1        0        6           0
# 448      449 2011-01-20       2   1     3        0        6           0
# 228      229 2011-01-10       3   0     8        0        3           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 528           2  0.653333  0.597875  0.833333   0.214546     477        4495
# 722           1  0.245833  0.259471  0.515417   0.133083     408        1379
# 0             2  0.344167  0.363625  0.805833   0.160446     331         654
# 448           2  0.502500  0.486733  0.885417   0.192783    1033        2339
# 228           1  0.723333  0.666671  0.575417   0.143667     668        4026
#
#       cnt
# 528  4972
# 722  1787
# 0     985
# 448  3372
# 228  4694

# %%
hour_df.describe(include="all")
# Out:
#           instant                         dteday        season            yr  \
# count  17379.0000                            731  17379.000000  17379.000000
# mean    8690.0000  2011-01-16 15:02:12.968536320      2.501640      0.502561
# min        1.0000            2011-01-01 00:00:00      1.000000      0.000000
# 25%     4345.5000            2011-01-08 00:00:00      2.000000      0.000000
# 50%     8690.0000            2011-01-16 00:00:00      3.000000      1.000000
# 75%    13034.5000            2011-01-24 12:00:00      3.000000      1.000000
# max    17379.0000            2011-02-02 00:00:00      4.000000      1.000000
# std     5017.0295                            NaN      1.106918      0.500008
#
#                mnth            hr       holiday       weekday    workingday  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       6.537775     11.546752      0.028770      3.003683      0.682721
# ...

# %% [markdown]
# mencari jumlah penyewa antara casual dan register pada setiap season per tahun

# %%
hour_df.groupby(by=["yr", "season"]).agg({
    'casual': 'sum',
    'registered': 'sum'
})
# Out:
#            casual  registered
# yr season
# 0  1        21425      128575
#    2        77564      269752
#    3        95450      324200
#    4        52813      273324
# 1  1        39197      282151
#    2       125958      445315
#    3       130641      510838
#    4        76969      438507

# %% [markdown]
# mencari statistik penyewaan setiap musim

# %%
day_df.groupby(by=["season"]).agg({
    "cnt": ["sum", "max", "min", "mean"]
})
# Out:
#             cnt
#             sum   max   min         mean
# season
# 1        471348  7836   431  2604.132597
# 2        918589  8362   795  4992.331522
# 3       1061129  8714  1115  5644.303191
# 4        841613  8555    22  4728.162921

# %% [markdown]
# mencari perkembaang sewa setiap bulannya

# %%
hour_df.groupby(by=["yr", "mnth"]).agg({
    "cnt": "sum"
})
# Out:
#             cnt
# yr mnth
# 0  1      38189
#    2      48215
#    3      64045
#    4      94870
#    5     135821
#    6     143512
#    7     141341
#    8     136691
#    9     127418
#    10    123511
#    11    102167
#    12     87323
# 1  1      96744
#    2     103137
#    3     164875
#    4     174224
#    5     195865
#    6     202830
#    7     203607
#    8     214503
#    9     218573
#    10    198841
#    11    152664
#    12    123713

# %% [markdown]
# mencari jam favorite para penyewa

# %%
hour_df.groupby(by=["hr"]).cnt.sum().sort_values(ascending=False)
# Out:
# hr
# 17    336860
# 18    309772
# 8     261001
# 16    227748
# 19    226789
# 13    184919
# 12    184414
# 15    183149
# 14    175652
# 20    164550
# 9     159438
# 7     154171
# 11    151320
# 10    126257
# 21    125445
# 22     95612
# 23     63941
# 6      55132
# 0      39130
# 1      24164
# 2      16352
# 5      14261
# 3       8174
# 4       4428
# Name: cnt, dtype: int64

# %% [markdown]
# **Insight:**
# - Mengetahui perbandingan penyewa casual dan register pada setiap musim
# - Mengetahui statistik penyewaan sepeda pada satu hari dalam setiap musim
# - Mengetahui perkembangan penyewaan dalam setiap bulan
# - Mengetahui jam favorit para penyewa

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1:

# %%
customer_data = hour_df.groupby(by=["yr", "season"]).agg({
    'casual': 'sum',
    'registered': 'sum'
}).reset_index()

customer_data['yr_season'] = customer_data['yr'].astype(str) + '-' + customer_data['season'].astype(str)

ind = np.arange(len(customer_data))
width = 0.35

fig, ax = plt.subplots(figsize=(10, 6))

bar1 = ax.bar(ind - width/2, customer_data['casual'], width, label='Penyewa Casual')
bar2 = ax.bar(ind + width/2, customer_data['registered'], width, label='Penyewa Registered')

ax.set_xlabel('Year and Season')
ax.set_ylabel('Jumlah Penyewa')
ax.set_title('Perbandingan penyewa Casual dan Register')

ax.set_xticks(ind)
ax.set_xticklabels([f'{customer_data["yr"][i]}-{customer_data["season"][i]}' for i in range(len(customer_data))])

ax.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Pertanyaan 2:

# %%
season_data = day_df.groupby(by=["season"]).agg({
    "cnt": ["sum", "max", "min", "mean"]
})

season_data.columns = ['cnt_sum', 'cnt_max', 'cnt_min', 'cnt_mean']

plt.figure(figsize=(10, 6))

plt.plot(season_data.index, season_data['cnt_max'], label='Max penyewa', marker='o', color='green')
plt.plot(season_data.index, season_data['cnt_min'], label='Min penyewa', marker='o', color='red')
plt.plot(season_data.index, season_data['cnt_mean'], label='Mean penyewa', marker='o', color='orange')

plt.xlabel("Season")
plt.ylabel('Jumlah Penyewa')
plt.title('Statistik Penyewa Setiap Musim')

plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Pertanyaan 3:

# %%
monthly_data = hour_df.groupby(by=["yr", "mnth"]).agg({"cnt": "sum"}).reset_index()

plt.figure(figsize=(10, 6))

plt.plot(monthly_data['mnth'] + (monthly_data['yr'] * 12), monthly_data['cnt'], marker='o', linestyle='-', color='b')

plt.xlabel('Month (Year-Month)')
plt.ylabel('Total Penyewa')
plt.title('Grafik Sewa Sepeda dalam setiap Bulan')

plt.grid(True)
plt.xticks(ticks=range(1, 25), labels=[f'{y}-{m}' for y in range(0, 2) for m in range(1, 13)])

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Pertanyaan 4:

# %%
hourly_data = hour_df.groupby(by=["hr"]).cnt.sum().sort_values(ascending=True)

plt.figure(figsize=(10, 6))

hourly_data.plot(kind='barh', color='skyblue')

plt.xlabel('Total Penyewa')
plt.ylabel('Jam Sewa')
plt.title('Grafik Sewa Berdasarkan Jam')

plt.grid(axis='x')

plt.tight_layout()
plt.show()

# %% [markdown]
# Menyimpan data CVS ke file baru

# %%
day_df.to_csv("days.csv", index=False)
hour_df.to_csv("hours.csv", index=False)

# %% [markdown]
# **Insight:**
# - Menggunakan Bar Chart untuk melihat perbandingan Casual dengan register
# - Menggunakan line chart untuk melihat stasistik Maksimal, minimal, dan rata-rata
# - Menggunakan line chart untuk melihat perkembangan naik dan turunnya jumlah penyewa dalam setiap bulan
# - Menggunakan Bar Chart untuk menampilkan dan mengurutkan jam favorite penyewa

# %% [markdown]
# ## Analisis Lanjutan (Opsional)

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Conclution pertanyaan 1 : Penyewa Casual relatif lebih rendah dibandingkan penyewa Register untuk setiap musimnya.
# - Conclution pertanyaan 2 : Musim 4 (musim dingin) pernah memiliki paling sedikit penyewa dalam satu hari, tapi juga memiliki paling banyak dalam satu hari.
# - Conclution pertanyaan 3 : Pada bulan desember ada penurunan jumlah sewa, yang perlahan menaik pada bulan pebruari.
# - Conclution pertanyaan 4 : Sewa tertinggi berada di jam 17 sedangkan paling sedikit ada di jam 4.
